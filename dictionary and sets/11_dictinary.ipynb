# %%
info={
    "name":"abhiyan",
    "list":[1,2,3,4,5],
    "colors":{
        "rojo":"red",
        "goro":"white"},

    "tuple":"unmutable"
}
print(info["list"])
# Out:
# [1, 2, 3, 4, 5]

# %%
info["name"]='aayusa'
info
# Out:
# {'name': 'aayusa',
#  'list': [1, 2, 3, 4, 5],
#  'colors': {'rojo': 'red', 'goro': 'white'},
#  'tuple': 'unmutable'}
