# %% [markdown]
# creating a Data Frame

# %%
import pandas as pd
my_data ={
    'cars':['BMW','MCLAREN','AUDI'],
    'milage':[9,8,9]
}
res =pd.DataFrame(my_data)

print(res)

res.to_csv('cars.csv',index=False)
# res.to_excel("cars1.xlsx",index= False)
# Out:
#       cars  milage
# 0      BMW       9
# 1  MCLAREN       8
# 2     AUDI       9

# %%
# read a excel file

import pandas as pd
df = pd.read_excel('SampleSuperstore.xlsx')
print(df.to_string())

# %%
# checking pandas version

import pandas as pd
print(pd.__version__)
# Out:
# 3.0.3
