# %%
# one dimensional array holding data of any type

import pandas as pd
import numpy as np
a=np.array([1.005,2,'sam',True])
ser= pd.Series(a)
print(ser)
print(ser[3])
# Out:
# 0    1.005
# 1        2
# 2      sam
# 3     True
# dtype: str
# True

# %% [markdown]
# # create label

# %%
# index method is used
import pandas as pd
a=[1,3,5,7,4]
val = pd.Series(a,index=['p','q','r','s','t'])

print(val)
print(val['q'])
# Out:
# p    1
# q    3
# r    5
# s    7
# t    4
# dtype: int64
# 3

# %%
import pandas as pd
calories={
    "day_1" : 430,
    "day_2":  200,
    "day3":842
}

val= pd.Series(calories,index=['day_1','day3'])
print(val)
# Out:
# day_1    430
# day3     842
# dtype: int64
