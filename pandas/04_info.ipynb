# %%
import pandas as pd
df= pd.read_csv('data.csv')

print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 5.4 KB
# None

# %% [markdown]
# # describe() method

# %%
import pandas as pd
data={
    'name':['abhiyan','ram','shyam','john'],
    'age':[20,30,18,25],
    'grade':[4.0,3.6,3.72,3.99],
    'marks':[98,88,93,96]

}
df= pd.DataFrame(data)
print(df)
print("Discription of the given data frame is:\n")

print(df.describe())

print(f'shape:{df.shape}')
print(f'column:{df.columns}')
# Out:
#       name  age  grade  marks
# 0  abhiyan   20   4.00     98
# 1      ram   30   3.60     88
# 2    shyam   18   3.72     93
# 3     john   25   3.99     96
# Discription of the given data frame is:
#
#              age     grade      marks
# count   4.000000  4.000000   4.000000
# mean   23.250000  3.827500  93.750000
# std     5.377422  0.199562   4.349329
# min    18.000000  3.600000  88.000000
# 25%    19.500000  3.690000  91.750000
# 50%    22.500000  3.855000  94.500000
# 75%    26.250000  3.992500  96.500000
# max    30.000000  4.000000  98.000000
# shape:(4, 4)
# column:Index(['name', 'age', 'grade', 'marks'], dtype='str')
