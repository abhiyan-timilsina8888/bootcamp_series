# %% [markdown]
# # pandas are the python libraries used to analyze data.

# %%
import pandas as pd
df= pd.read_csv('data.csv')
print(df.to_string())
# Out:
# The kernel failed to start as the Python Environment 'Python 3.14.3' is no longer available. Consider selecting another kernel or refreshing the list of Python Environments.

# %%
import sys
print(sys.executable)
# Out:
# /Users/abhiyantimilsina/Developer/bootcamp_series/pandas/.venv/bin/python
