# %% [markdown]
# 1. Display Top 5 Rows of The Dataset
# 2. Check the Last 3 Rows of The Dataset
# 3. Find Shape of Our Dataset (Number of Rows & Number of Columns)
# 4. Get Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement
# 5. Get Overall Statistics About The Dataframe
# 6. Total Number of App Titles Contain Astrology
# 7. Find Average App Rating
# 8.  Find Total Number of Unique Category
# 9. Which Category Getting The Highest Average Rating?
# 10. Find Total Number of App having 5 Star Rating
# 11. Find Average Value of Reviews
# 12. Find Total Number of Free and Paid Apps
# 13.  Which App Has Maximum Reviews?
# 14. Display Top 5 Apps Having Highest Reviews
# 15. Find Average Rating of Free and Paid Apps
# 16. Display Top  5 Apps Having Maximum Installs

# %%
import pandas as pd
df=pd.read_csv("googleplaystore.csv")
print(df)
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# # 1. Display Top 5 Rows of The Dataset

# %%
print(df.head())

# %% [markdown]
# # 2. Check the Last 3 Rows of The Dataset

# %%
print(df.tail(3))

# %% [markdown]
# # 3. Find Shape of Our Dataset (Number of Rows & Number of Columns)

# %%
print(df.shape)
print("rows:",df.shape[0])
print("columns:",df.shape[1])
# Out:
# (10841, 13)
# rows: 10841
# columns: 13

# %% [markdown]
# # 4. Get Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement

# %%
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  str
#  1   Category        10841 non-null  str
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  str
#  4   Size            10841 non-null  str
#  5   Installs        10841 non-null  str
#  6   Type            10840 non-null  str
#  7   Price           10841 non-null  str
#  8   Content Rating  10840 non-null  str
#  9   Genres          10841 non-null  str
#  10  Last Updated    10841 non-null  str
#  11  Current Ver     10833 non-null  str
#  12  Android Ver     10838 non-null  str
# dtypes: float64(1), str(12)
# memory usage: 1.1 MB
# None

# %% [markdown]
# # 5. Get Overall Statistics About The Dataframe

# %%
print(df.describe(include="all"))
# Out:
#            App Category       Rating Reviews                Size    Installs  \
# count    10841    10841  9367.000000   10841               10841       10841
# unique    9660       34          NaN    6002                 462          22
# top     ROBLOX   FAMILY          NaN       0  Varies with device  1,000,000+
# freq         9     1972          NaN     596                1695        1579
# mean       NaN      NaN     4.193338     NaN                 NaN         NaN
# std        NaN      NaN     0.537431     NaN                 NaN         NaN
# min        NaN      NaN     1.000000     NaN                 NaN         NaN
# 25%        NaN      NaN     4.000000     NaN                 NaN         NaN
# 50%        NaN      NaN     4.300000     NaN                 NaN         NaN
# 75%        NaN      NaN     4.500000     NaN                 NaN         NaN
# max        NaN      NaN    19.000000     NaN                 NaN         NaN
#
# ...

# %% [markdown]
# # 6. Total Number of App Titles Contain Astrology

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='str')

# %%
# print(df["App"].value_counts())
print(sum(df["App"].str.contains("Astrology",case= False)))
# Out:
# 3

# %% [markdown]
# # 7. Find Average App Rating

# %%
print(df["Rating"].mean())
# Out:
# 4.193338315362443

# %% [markdown]
# # 8. Find Total Number of Unique Category

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='str')

# %%
df["Category"].nunique()
# Out:
# 34

# %% [markdown]
# # 9. Which Category Getting The Highest Average Rating?

# %%
df.groupby("Category")["Rating"].mean().head().sort_values(ascending= False)
# Out:
# Category
# 1.9                    19.000000
# ART_AND_DESIGN          4.358065
# BOOKS_AND_REFERENCE     4.346067
# BEAUTY                  4.278571
# AUTO_AND_VEHICLES       4.190411
# Name: Rating, dtype: float64

# %% [markdown]
# # 10. Find Total Number of App having 5 Star Rating

# %%
print(df[df["Rating"]==5]["App"].value_counts().sum())
# Out:
# 274

# %% [markdown]
# # 11. Find Average Value of Reviews

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='str')

# %%
df["Reviews"]=pd.to_numeric(df["Reviews"],errors="coerce")

print(df["Reviews"].mean())
# Out:
# 444152.89603321033

# %% [markdown]
# # 12. Find Total Number of Free and Paid Apps

# %%
df["Type"].value_counts()
# Out:
# Type
# Free    10039
# Paid      800
# 0           1
# Name: count, dtype: int64

# %% [markdown]
# # 13.  Which App Has Maximum Reviews?

# %%
df.columns
print(df["Reviews"].max())
print(df[df["Reviews"]==df["Reviews"].max()]["App"])
# Out:
# 78158306.0
# 2544    Facebook
# Name: App, dtype: str

# %% [markdown]
# # 14. Display Top 5 Apps Having Highest Reviews

# %%
index=df["Reviews"].sort_values(ascending=False).head().index
df.iloc[index]["App"]
# Out:
# 2544              Facebook
# 3943              Facebook
# 381     WhatsApp Messenger
# 336     WhatsApp Messenger
# 3904    WhatsApp Messenger
# Name: App, dtype: str

# %% [markdown]
# # 15. Find Average Rating of Free and Paid Apps

# %%
df.columns
df["Type"].unique()
# Out:
# <StringArray>
# ['Free', 'Paid', nan, '0']
# Length: 4, dtype: str

# %%
print(df.groupby('Type').mean(numeric_only=True)["Rating"])
# Out:
# Type
# 0       19.000000
# Free     4.186203
# Paid     4.266615
# Name: Rating, dtype: float64

# %%
print("rating of free app:",df[df["Type"]=="Free"].mean(numeric_only=True)["Rating"])
print("rating of paid app:",df[df["Type"]=="Paid"].mean(numeric_only=True)["Rating"])
# Out:
# rating of free app: 4.186202546163551
# rating of paid app: 4.26661514683153

# %% [markdown]
# # 16. Display Top  5 Apps Having Maximum Installs

# %%
df.columns
print(df["Installs"].unique())
# Out:
# <StringArray>
# [       '10,000+',       '500,000+',     '5,000,000+',    '50,000,000+',
#        '100,000+',        '50,000+',     '1,000,000+',    '10,000,000+',
#          '5,000+',   '100,000,000+', '1,000,000,000+',         '1,000+',
#    '500,000,000+',            '50+',           '100+',           '500+',
#             '10+',             '1+',             '5+',             '0+',
#               '0',           'Free']
# Length: 22, dtype: str

# %%
df["Installs"]=df["Installs"].str.replace(r"[,+]","",regex= True)
df['Installs']=pd.to_numeric(df["Installs"],errors= "coerce")
print(df["Installs"].dtype)

# %%
index=df["Installs"].sort_values(ascending= False).head().index
df.iloc[index]["App"]
# Out:
# 3896                              Subway Surfers
# 3943                                    Facebook
# 335     Messenger – Text and Video Chat for Free
# 3523                                Google Drive
# 3565                                Google Drive
# Name: App, dtype: str
