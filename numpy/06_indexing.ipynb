# %%
import numpy as np
arr=np.array([1,2,3,4])
print(arr[3])
# Out:
# 4

# %%
import numpy as np
arr= np.array([1,0,2,1,4])
print(arr[2]+arr[3])
# Out:
# 3

# %%
#negative indexing
import numpy as np 
arr=np.array([1,2,3,4])
print(arr[-2])
# Out:
# 3
