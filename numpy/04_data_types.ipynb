# %% [markdown]
# dtype is used to assign array's type.
# dtype='i'/'S'/'f' can be used.

# %%
import numpy as np
arr= np.array([1,2,34], dtype= 'f')
print(arr)
print(arr.dtype)
# Out:
# [ 1.  2. 34.]
# float32

# %% [markdown]
# # forcing the data to change type

# %%
import numpy as np
arr= np.array([1.1,2.2,3.2])
n_arr=arr.astype('i') # int can also be used 64 bytes
print(n_arr)
print(n_arr.dtype)

# %%
#integer to boolen

import numpy as np
arr = np.array([-1,1,2,3,0])
n_arr= arr.astype(bool)
print(n_arr)
print(n_arr.dtype)
# Out:
# [ True  True  True  True False]
# bool
