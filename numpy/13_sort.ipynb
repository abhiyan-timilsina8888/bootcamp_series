# %%
import numpy as np
arr= np.array([14,0,3,6])
print(np.sort(arr))
# Out:
# [ 0  3  6 14]

# %%
import numpy as jp
arr= jp.array(['apple','aanaconda','aaaaabhiyan'])
print(jp.sort(arr))
# Out:
# ['aaaaabhiyan' 'aanaconda' 'apple']

# %%
import numpy as np
arr= np.array([True,False,True])
print(np.sort(arr))
# Out:
# [False  True  True]
